# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import seaborn as sns
import scipy
from scipy import stats

# %% [markdown]
# # Import file

# %%
f = open('/Users/michelle/Desktop/final-project/SMSSpamCollection.txt', 'r+')

# %%
f.close()

# %%
f = np.genfromtxt(fname='/Users/michelle/Desktop/final-project/SMSSpamCollection.txt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wn/s_csn73d3zdf0m_nh7011bsh0000gn/T/ipykernel_2938/3912089722.py in <module>
# ----> 1 f = np.genfromtxt(fname='/Users/michelle/Desktop/final-project/SMSSpamCollection.txt')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2120             # Raise an exception ?
#    2121             if invalid_raise:
# -> 2122                 raise ValueError(errmsg)
#    2123             # Issue a warning ?
#    2124             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 7 columns instead of 21)
# ...

# %%
print(SMSSpamCollection.lower())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wn/s_csn73d3zdf0m_nh7011bsh0000gn/T/ipykernel_2938/2672137217.py in <module>
# ----> 1 print(SMSSpamCollection.lower())
#
# NameError: name 'SMSSpamCollection' is not defined

# %%
text.split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wn/s_csn73d3zdf0m_nh7011bsh0000gn/T/ipykernel_2938/855229320.py in <module>
# ----> 1 text.split()
#
# NameError: name 'text' is not defined
